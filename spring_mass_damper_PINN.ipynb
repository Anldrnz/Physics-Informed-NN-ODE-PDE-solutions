# %% [markdown]
# <a href="https://colab.research.google.com/github/Anldrnz/Physics-Informed-NN-ODE-PDE-solutions/blob/main/spring_mass_damper_PINN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mass spring damper system:**

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import math
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## **Visual Related Methods**

# %%
def save_gif_PIL(outfile, files, fps=5, loop=0):
    "Helper function for saving GIFs"
    imgs = [Image.open(file) for file in files]
    imgs[0].save(fp=outfile, format='GIF', append_images=imgs[1:], save_all=True, duration=int(1000/fps), loop=loop)

# %%
def plot_result(x,y,x_data,y_data,yh,xp=None):
    "Pretty plot training results"
    plt.figure(figsize=(8,4))
    plt.plot(x,y, color="grey", linewidth=2, alpha=0.8, label="Exact solution")
    plt.plot(x,yh, color="tab:blue", linewidth=4, alpha=0.8, label="Neural network prediction")
    plt.scatter(x_data, y_data, s=60, color="tab:orange", alpha=0.4, label='Training data')
    if xp is not None:
        plt.scatter(xp, -0*torch.ones_like(xp), s=60, color="tab:green", alpha=0.4, 
                    label='Physics loss training locations')
    l = plt.legend(loc=(1.01,0.34), frameon=False, fontsize="large")
    plt.setp(l.get_texts(), color="k")
    plt.xlim(-0.05, 1.05)
    plt.ylim(-1.1, 1.1)
    plt.text(1.065,0.7,"Training step: %i"%(i+1),fontsize="xx-large",color="k")
    plt.axis("off")

# %% [markdown]
# ## **Phsyics Function Declarations**

# %%
# Constants
m = 1 # mass
k = 400 # spring coefficient
b = 4 # damping coefficient
external_force = 0

def oscillator(d, w0, x):
    """Defines the analytical solution to the 1D underdamped harmonic oscillator problem"""
    assert d < w0
    w = np.sqrt(w0**2-d**2)
    phi = np.arctan(-d/w)
    A = 1/(2*np.cos(phi))
    cos = torch.cos(phi+w*x)
    sin = torch.sin(phi+w*x)
    exp = torch.exp(-d*x)
    y  = exp*2*A*cos
    return y

# %%
def f(t, net):
    phy_t = net(t)
    dx  = torch.autograd.grad(phy_t, t, torch.ones_like(phy_t), create_graph=True)[0] # Velocity
    dx2 = torch.autograd.grad(dx,  t, torch.ones_like(dx),  create_graph=True)[0] # Acceleration
    eqn = (m*dx2 + b*dx + k*phy_t + external_force)
    return eqn

# %% [markdown]
# ## **The Exact Solution**

# %%
d, w0 = b/(2*m), math.sqrt(k/m)

# get the analytical solution over the full domain
x = torch.linspace(0,1,500).view(-1,1)
y = oscillator(d, w0, x).view(-1,1)
print(x.shape, y.shape)

# slice out a small number of points from the LHS of the domain
x_data = x[0:200:20]
y_data = y[0:200:20]
print(x_data.shape, y_data.shape)

plt.figure()
plt.plot(x, y, label="Exact solution")
plt.scatter(x_data, y_data, color="tab:orange", label="Training data")
plt.legend()
plt.show()
# Out:
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([10, 1]) torch.Size([10, 1])

# %% [markdown]
# ## **`Creating the Model`**

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.hidden_layer1 = nn.Linear(1,20)
        self.hidden_layer2 = nn.Linear(20,20)
        self.output_layer = nn.Linear(20,1)

    def forward(self, t):
        input = t
        layer1_out = torch.tanh(self.hidden_layer1(input))
        layer2_out = torch.tanh(self.hidden_layer2(layer1_out))
        output = self.output_layer(layer2_out) ## For regression, no activation is used in output layer
        return output

# %%
net = Net()
net = net.to(device)
mse_cost_function = torch.nn.MSELoss() # Mean squared error
optimizer = torch.optim.Adam(net.parameters())

# %% [markdown]
# ## **Training and Fitting**

# %%
#epoch = 0
#loss = torch.from_numpy(np.array([1]))
#while loss.data > 0.0005:
    #epoch += 1

files = []
iterations = 12000
for i in range(iterations):
    optimizer.zero_grad() # to make the gradients zero
    
    # Loss based on observed data
    #t_data = Variable(torch.from_numpy(t_sample).float(), requires_grad=False).to(device)
    net_x_out = net(x_data) # output of u(t)
    mse_u = mse_cost_function(net_x_out, y_data)

    # compute the "physics loss"
    phy_input = torch.linspace(0,1,30).view(-1,1).requires_grad_(True)
    physics = f(phy_input, net)
    all_zeros = np.zeros((len(physics),1))
    mse_f = (1e-4)*torch.mean(physics**2)
    #mse_f = mse_cost_function(physics, pt_all_zeros.reshape(len(pt_all_zeros),1))
    
    # Combining the loss functions
    loss = mse_u + mse_f
    
    loss.backward()
    optimizer.step()

    if (i+1) % 150 == 0: 
        
        net_x_out = net(x).detach()
        xp = phy_input.detach()
        
        plot_result(x,y,x_data,y_data,net_x_out,xp)
        
        file = "pinn_%.8i.png"%(i+1)
        plt.savefig(file, bbox_inches='tight', pad_inches=0.1, dpi=100, facecolor="white")
        files.append(file)
        
        if (i+1) % 6000 == 0: plt.show()
        else: plt.close("all")

    with torch.autograd.no_grad():
      if i % 500 == 0:
        print(i,"Traning Loss:",loss.data,"mse_u:",mse_u,"mse_f",mse_f)

save_gif_PIL("pinn.gif", files, fps=20, loop=0)
# Out:
# 0 Traning Loss: tensor(0.1198) mse_u: tensor(0.0673, grad_fn=<MseLossBackward0>) mse_f tensor(0.0525, grad_fn=<MulBackward0>)
# 500 Traning Loss: tensor(0.0623) mse_u: tensor(0.0262, grad_fn=<MseLossBackward0>) mse_f tensor(0.0361, grad_fn=<MulBackward0>)
# 1000 Traning Loss: tensor(0.0341) mse_u: tensor(0.0070, grad_fn=<MseLossBackward0>) mse_f tensor(0.0270, grad_fn=<MulBackward0>)
# 1500 Traning Loss: tensor(0.0216) mse_u: tensor(0.0035, grad_fn=<MseLossBackward0>) mse_f tensor(0.0181, grad_fn=<MulBackward0>)
# 2000 Traning Loss: tensor(0.0147) mse_u: tensor(0.0014, grad_fn=<MseLossBackward0>) mse_f tensor(0.0133, grad_fn=<MulBackward0>)
# 2500 Traning Loss: tensor(0.0124) mse_u: tensor(0.0010, grad_fn=<MseLossBackward0>) mse_f tensor(0.0114, grad_fn=<MulBackward0>)
# 3000 Traning Loss: tensor(0.0089) mse_u: tensor(0.0006, grad_fn=<MseLossBackward0>) mse_f tensor(0.0083, grad_fn=<MulBackward0>)
# 3500 Traning Loss: tensor(0.0048) mse_u: tensor(0.0003, grad_fn=<MseLossBackward0>) mse_f tensor(0.0045, grad_fn=<MulBackward0>)
# 4000 Traning Loss: tensor(0.0030) mse_u: tensor(0.0001, grad_fn=<MseLossBackward0>) mse_f tensor(0.0028, grad_fn=<MulBackward0>)
# 4500 Traning Loss: tensor(0.0022) mse_u: tensor(9.4945e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0021, grad_fn=<MulBackward0>)
# 5000 Traning Loss: tensor(0.0017) mse_u: tensor(6.1393e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0017, grad_fn=<MulBackward0>)
# 5500 Traning Loss: tensor(0.0014) mse_u: tensor(4.5977e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0013, grad_fn=<MulBackward0>)
# 6000 Traning Loss: tensor(0.0011) mse_u: tensor(2.9434e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0011, grad_fn=<MulBackward0>)
# 6500 Traning Loss: tensor(0.0009) mse_u: tensor(2.1542e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0009, grad_fn=<MulBackward0>)
# 7000 Traning Loss: tensor(0.0008) mse_u: tensor(1.9861e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0008, grad_fn=<MulBackward0>)
# 7500 Traning Loss: tensor(0.0007) mse_u: tensor(1.5011e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0007, grad_fn=<MulBackward0>)
# 8000 Traning Loss: tensor(0.0006) mse_u: tensor(1.2157e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0006, grad_fn=<MulBackward0>)
# 8500 Traning Loss: tensor(0.0005) mse_u: tensor(1.0003e-05, grad_fn=<MseLossBackward0>) mse_f tensor(0.0005, grad_fn=<MulBackward0>)
# 9000 Traning Loss: tensor(0.0005) mse_u: tensor(8.3434e-06, grad_fn=<MseLossBackward0>) mse_f tensor(0.0005, grad_fn=<MulBackward0>)
# 9500 Traning Loss: tensor(0.0004) mse_u: tensor(6.9726e-06, grad_fn=<MseLossBackward0>) mse_f tensor(0.0004, grad_fn=<MulBackward0>)
# 10000 Traning Loss: tensor(0.0004) mse_u: tensor(5.9049e-06, grad_fn=<MseLossBackward0>) mse_f tensor(0.0004, grad_fn=<MulBackward0>)
# 10500 Traning Loss: tensor(0.0004) mse_u: tensor(5.0321e-06, grad_fn=<MseLossBackward0>) mse_f tensor(0.0004, grad_fn=<MulBackward0>)
# 11000 Traning Loss: tensor(0.0004) mse_u: tensor(4.3336e-06, grad_fn=<MseLossBackward0>) mse_f tensor(0.0004, grad_fn=<MulBackward0>)
# 11500 Traning Loss: tensor(0.0003) mse_u: tensor(3.7808e-06, grad_fn=<MseLossBackward0>) mse_f tensor(0.0003, grad_fn=<MulBackward0>)

# %% [markdown]
# ## **Observing the Final Result and Comparing**

# %%
# plot lines
plt.figure(figsize=(20, 8))
plt.plot(x, y, label = "Exact Solution", color="black")

# Training data
plt.plot(x_data, y_data, 'D', color="green")

plt.plot(x, net(x).detach(), "r--", label = "NN Solution", linewidth = 2)

# %%
# Save Model
torch.save(net.state_dict(), "mass_spr_model.pt")

# %% [markdown]
# ## ***Diminishing Mass Case***

# %% [markdown]
# ### **Declaring functions and finding the exact solutions**

# %%
# Constants
m = 1 # mass
k = 400 # spring coefficient
b = 4 # damping coefficient
external_force = 0

def oscillator_m(x):
    """Defines the analytical solution to the 1D underdamped harmonic oscillator problem"""
    m = 1 - 0.15*torch.sin(2*math.pi*x) - 0.005*x
    d, w0 = b/(2*m), torch.sqrt(k/m)
    #m = 1.2
    #d, w0 = b/(2*m), math.sqrt(k/m)
    w = np.sqrt(w0**2-d**2)
    phi = np.arctan(-d/w)
    A = 1/(2*np.cos(phi))
    cos = torch.cos(phi+w*x)
    sin = torch.sin(phi+w*x)
    exp = torch.exp(-d*x)
    y  = exp*2*A*cos
    return y

# %%
def f(t, net):
    #m = 1.2
    phy_t = net(t)
    dx  = torch.autograd.grad(phy_t, t, torch.ones_like(phy_t), create_graph=True)[0] # Velocity
    dx2 = torch.autograd.grad(dx,  t, torch.ones_like(dx),  create_graph=True)[0] # Acceleration
    eqn = (m*dx2 + b*dx + k*phy_t + external_force)
    return eqn

# %%
# get the analytical solution over the full domain
x = torch.linspace(0,1,500).view(-1,1)
y = oscillator(b/(2*m), math.sqrt(k/m), x).view(-1,1)
y_m = oscillator_m(x).view(-1,1)
print(x.shape, y.shape)

# slice out a small number of points from the LHS of the domain
x_data = x[0:300:20]
y_data = y_m[0:300:20]
print(x_data.shape, y_data.shape)

plt.figure()
plt.plot(x, y, label="Exact solution constant mass")
plt.plot(x, y_m, label="Exact solution decreasing mass", color='red')
plt.scatter(x_data, y_data, color="tab:green", label="Training data")
plt.legend()
plt.show()
# Out:
# 2.0 20.0
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([15, 1]) torch.Size([15, 1])

# %% [markdown]
# ### **Training and Fitting**

# %%
files = []
iterations = 12000
for i in range(iterations):
    optimizer.zero_grad() # to make the gradients zero
    
    # Loss based on observed data
    #t_data = Variable(torch.from_numpy(t_sample).float(), requires_grad=False).to(device)
    net_x_out = net(x_data) # output of u(t)
    mse_u = torch.mean((net_x_out - y_data)**2)

    # compute the "physics loss"
    phy_input = torch.linspace(0,1,30).view(-1,1).requires_grad_(True)
    physics = f(phy_input, net)
    mse_f = torch.mean(physics**2)*(1e-4)
    
    # Combining the loss functions
    loss = mse_u + mse_f
    
    loss.backward()
    optimizer.step()

    if (i+1) % 150 == 0: 
        
        net_x_out = net(x).detach()
        xp = phy_input.detach()
        
        plot_result(x,y,x_data,y_data,net_x_out,xp)
        
        file = "pinn_%.8i.png"%(i+1)
        plt.savefig(file, bbox_inches='tight', pad_inches=0.1, dpi=100, facecolor="white")
        files.append(file)
        
        if (i+1) % 6000 == 0: plt.show()
        else: plt.close("all")

    with torch.autograd.no_grad():
      if i % 500 == 0:
        print(i,"Traning Loss:",loss.data,"mse_u:",mse_u,"mse_f",mse_f)

save_gif_PIL("pinn.gif", files, fps=20, loop=0)

# %% [markdown]
# ### **Observing the Final Result and Comparing**

# %%
# plot lines
plt.figure(figsize=(20, 8))
plt.plot(x, y, label="Exact solution constant mass")
plt.plot(x, y_m, label="Exact solution decreasing mass", color='red')
# Training data
plt.plot(x_data, y_data, 'D', color="green", label="Training data")
# PINN
plt.plot(x, net(x).detach(), "k--", label = "NN Solution", linewidth = 2)
